# %% [markdown]
# # Close position

# %% [markdown]
# ## Prepare client

# %% [markdown]
# ## API Key

# %%
import os

API_KEY = os.getenv('API_KEY')
API_SECRET = os.getenv('API_SECRET')

# %% [markdown]
# ## Instantiate Python client for Alpaca API

# %%
from alpaca.trading.client import TradingClient
client = TradingClient(API_KEY, API_SECRET, paper=True)

# %% [markdown]
# ## Account status

# %% [markdown]
# ### Orders

# %%
import pandas as pd
from alpaca.trading import requests

request = requests.GetOrdersRequest(status='all')
orders = client.get_orders(request)

pd.DataFrame([order.dict() for order in orders])
# Out:
#                                      id                       client_order_id  \
# 0  66aa53a1-8af3-41b0-b820-048c8a2bbe9d  a822fe4d-7335-44a7-9f0d-a7f1cf7699ef
# 1  db731111-7963-412a-b6cf-b016dabf8f6a  aac8d44e-8f01-4919-9c89-43d32a8ddd62
# 2  cfead12e-64fc-455f-91d4-942d48655d9b  0d73629e-9c53-460a-a717-743cda6c7778
# 3  65d7126c-7d1e-4a56-b80a-304b7f7224a9  eb521d05-b53d-49c3-90d3-acc7a4aaf733
# 4  8c0bf1f4-d58d-4935-8e5e-cdb3ce03e2a0  08443e02-693e-454f-8882-ab6d1f95645a
# 5  8b5448a9-4d7c-450c-8ee4-17eb479f1e0d  8eec6f08-895d-4dca-9315-f0f57401fb01
#
#                         created_at                       updated_at  \
# 0 2024-06-07 18:09:56.333066+00:00 2024-06-07 18:09:56.376947+00:00
# 1 2024-06-07 18:08:28.449436+00:00 2024-06-07 18:08:28.476904+00:00
# 2 2024-06-07 17:49:41.577287+00:00 2024-06-07 17:49:41.626751+00:00
# 3 2024-06-07 17:49:25.559351+00:00 2024-06-07 17:49:25.577523+00:00
# 4 2024-04-03 14:16:06.430993+00:00 2024-04-03 14:16:06.463166+00:00
# 5 2024-04-03 14:15:10.739103+00:00 2024-04-03 14:15:10.763264+00:00
#
#                       submitted_at                        filled_at  \
# 0 2024-06-07 18:09:56.333066+00:00 2024-06-07 18:09:56.335383+00:00
# 1 2024-06-07 18:08:28.449436+00:00 2024-06-07 18:08:28.451853+00:00
# 2 2024-06-07 17:49:41.577287+00:00 2024-06-07 17:49:41.579824+00:00
# 3 2024-06-07 17:49:25.559351+00:00 2024-06-07 17:49:25.562535+00:00
# 4 2024-04-03 14:16:06.429560+00:00 2024-04-03 14:16:06.433274+00:00
# 5 2024-04-03 14:15:10.738413+00:00 2024-04-03 14:15:10.741579+00:00
#
#   expired_at canceled_at failed_at replaced_at replaced_by replaces  \
# 0       None        None      None        None        None     None
# 1       None        None      None        None        None     None
# 2       None        None      None        None        None     None
# 3       None        None      None        None        None     None
# 4       None        None      None        None        None     None
# 5       None        None      None        None        None     None
#
#                                asset_id   symbol        asset_class notional  \
# 0  276e2673-764b-4ab6-a611-caf665ca6340  BTC/USD  AssetClass.CRYPTO    10000
# 1  276e2673-764b-4ab6-a611-caf665ca6340  BTC/USD  AssetClass.CRYPTO     None
# 2  276e2673-764b-4ab6-a611-caf665ca6340  BTC/USD  AssetClass.CRYPTO    10000
# 3  276e2673-764b-4ab6-a611-caf665ca6340  BTC/USD  AssetClass.CRYPTO    10000
# 4  276e2673-764b-4ab6-a611-caf665ca6340  BTC/USD  AssetClass.CRYPTO     None
# 5  276e2673-764b-4ab6-a611-caf665ca6340  BTC/USD  AssetClass.CRYPTO   100000
#
#            qty   filled_qty filled_avg_price        order_class  \
# 0         None  0.141353974        69533.571  OrderClass.SIMPLE
# 1  0.744037332  0.744037332  69481.340815723  OrderClass.SIMPLE
# 2         None  0.139473818          70484.8  OrderClass.SIMPLE
# 3         None  0.139473818        70520.641  OrderClass.SIMPLE
# 4            1            1  66846.939677416  OrderClass.SIMPLE
# 5         None  1.469460718  66922.092477295  OrderClass.SIMPLE
#
#          order_type              type            side    time_in_force  \
# 0  OrderType.MARKET  OrderType.MARKET   OrderSide.BUY  TimeInForce.GTC
# 1  OrderType.MARKET  OrderType.MARKET  OrderSide.SELL  TimeInForce.GTC
# 2  OrderType.MARKET  OrderType.MARKET   OrderSide.BUY  TimeInForce.GTC
# 3  OrderType.MARKET  OrderType.MARKET   OrderSide.BUY  TimeInForce.GTC
# 4  OrderType.MARKET  OrderType.MARKET  OrderSide.SELL  TimeInForce.GTC
# 5  OrderType.MARKET  OrderType.MARKET   OrderSide.BUY  TimeInForce.GTC
#
#   limit_price stop_price              status  extended_hours  legs  \
# 0        None       None  OrderStatus.FILLED           False  None
# 1        None       None  OrderStatus.FILLED           False  None
# 2        None       None  OrderStatus.FILLED           False  None
# 3        None       None  OrderStatus.FILLED           False  None
# 4        None       None  OrderStatus.FILLED           False  None
# 5        None       None  OrderStatus.FILLED           False  None
#
#   trail_percent trail_price   hwm
# 0          None        None  None
# 1          None        None  None
# 2          None        None  None
# 3          None        None  None
# 4          None        None  None
# 5          None        None  None

# %% [markdown]
# ### Positions

# %%
positions = client.get_all_positions()

df = pd.DataFrame([position.dict() for position in positions]).set_index('symbol')
df
# Out:
#                                     asset_id              exchange  \
# symbol
# BTCUSD  64bbff51-59d6-4b3c-9351-13ad85e3c752  AssetExchange.CRYPTO
#
#               asset_class  asset_marginable avg_entry_price          qty  \
# symbol
# BTCUSD  AssetClass.CRYPTO             False       69533.571  0.141000589
#
#                      side market_value      cost_basis  unrealized_pl  \
# symbol
# BTCUSD  PositionSide.LONG  9729.040641  9804.274466273  -75.233825273
#
#             unrealized_plpc unrealized_intraday_pl unrealized_intraday_plpc  \
# symbol
# BTCUSD  -0.0076735739632552       -75.233825273319      -0.0076735739632875
#
#        current_price lastday_price         change_today swap_rate  \
# symbol
# BTCUSD         69000     70693.396  -0.0239540904216852      None
#
#        avg_entry_swap_rate   usd qty_available
# symbol
# BTCUSD                None  None   0.141000589

# %% [markdown]
# ## Closing position

# %% [markdown]
# ### Select symbol

# %%
symbol = 'BTCUSD'

# %% [markdown]
# ### Prepare request

# %%
request = requests.ClosePositionRequest(percentage='10')

# %% [markdown]
# ### Submit the request to close position

# %%
response = client.close_position(symbol_or_asset_id=symbol, close_options=request)

# %%
pd.DataFrame(response.dict(), index=[0])
# Out:
#                                      id                       client_order_id  \
# 0  4e0f28c9-c00e-4f1d-9cb5-abc28dcd4e48  bb4e7bed-7896-4e92-8d14-b65584eb0a0e
#
#                         created_at                       updated_at  \
# 0 2024-06-07 18:10:09.699618+00:00 2024-06-07 18:10:09.700401+00:00
#
#                       submitted_at filled_at expired_at canceled_at failed_at  \
# 0 2024-06-07 18:10:09.699618+00:00      None       None        None      None
#
#   replaced_at replaced_by replaces                              asset_id  \
# 0        None        None     None  276e2673-764b-4ab6-a611-caf665ca6340
#
#     symbol        asset_class notional          qty filled_qty  \
# 0  BTC/USD  AssetClass.CRYPTO     None  0.014100058          0
#
#   filled_avg_price        order_class        order_type              type  \
# 0             None  OrderClass.SIMPLE  OrderType.MARKET  OrderType.MARKET
#
#              side    time_in_force limit_price stop_price  \
# 0  OrderSide.SELL  TimeInForce.GTC        None       None
#
#                     status  extended_hours  legs trail_percent trail_price  \
# 0  OrderStatus.PENDING_NEW           False  None          None        None
#
#     hwm
# 0  None

# %% [markdown]
# ### Check Profits
#
# https://app.alpaca.markets/account/activities
