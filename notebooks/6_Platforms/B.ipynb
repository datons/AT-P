# %%
GBPUSD = 3440
EURUSD = 3438
USDJPY = 3427
EURGBP = 3419
USDCAD = 3433
USDCHF = 3390
AUDUSD = 3411
NZDUSD = 3398
EURJPY = 3392
AUDCHF = 3395
XAUUSD = 3406
US30 = 3351
ETHUSD = 3443
BTCUSD = 3425
csrf = ""
BUY = 0
SELL = 1
MARKET = 0

# %%
from dx import Identity

# %%
identity = Identity("1210095684", "d2!^UJ4@h", "ftmo")
identity.login()
identity.buy(0.01, 0, 0, MARKET, "BTCUSD", BTCUSD)
# Out:
# 41|f25cb2d2-e1a5-43d1-901b-83874f4dec1c|0|X|
# 97|{"accountId":null,"body":"f25cb2d2-e1a5-43d1-901b-83874f4dec1c","type":"MESSAGE_BUS_INITIALIZED"}
# 125|{"accountId":null,"body":{"status":true,"statusCode":"","languageChanged":false,"errorCode":null},"type":"USER_LOGIN_STATUS"}
# 75|{"accountId":null,"body":{"serverTime":1718055891393},"type":"SERVER_INFO"}
# ...

# %%
identity.get_positions()
# Out:
# 41|468370a1-a12c-47f9-b2ce-faee344ec226|0|X|
# 97|{"accountId":null,"body":"468370a1-a12c-47f9-b2ce-faee344ec226","type":"MESSAGE_BUS_INITIALIZED"}
# 125|{"accountId":null,"body":{"status":true,"statusCode":"","languageChanged":false,"errorCode":null},"type":"USER_LOGIN_STATUS"}
# 75|{"accountId":null,"body":{"serverTime":1718055818711},"type":"SERVER_INFO"}
# ...

# %%
# Out:
# PAYLOAD {'directExchange': False, 'legs': [{'instrumentId': 3425, 'positionEffect': 'OPENING', 'ratioQuantity': 1, 'symbol': 'BTCUSD'}], 'limitPrice': 0, 'orderSide': 'BUY', 'orderType': 'MARKET', 'quantity': 0.01, 'requestId': 'gwt-uid-931-d9421865-7eaf-4836-bcfa-5deb22b08d19', 'timeInForce': 'GTC'}
# market order 409
