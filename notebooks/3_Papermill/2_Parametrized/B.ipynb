# %%
import papermill as pm

# %%
strategy = '../../2_Strategies/2_Bollinger Any/B.ipynb'

# %%
pm.execute_notebook(
    strategy,
    strategy.replace('B.ipynb', 'B_output.ipynb'),
    parameters=dict(
        symbol='NFLX',
        N_WINDOWS=20,
        K=2
    )
)
# Out:
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'cells': [{'attachments': {},
#    'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T11:59:47.460468',
#      'end_time': '2024-06-08T11:59:47.484427',
#      'duration': 0.023959,
#      'status': 'completed'}},
#    'source': '# Simulate Trading Bot Action',
#    'id': 'ad630ca9'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-06-08T11:59:47.493550',
#      'end_time': '2024-06-08T11:59:47.513908',
#      'duration': 0.020358,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-06-08T11:59:47.501041Z',
#      'iopub.execute_input': '2024-06-08T11:59:47.502355Z',
#      'iopub.status.idle': '2024-06-08T11:59:47.511764Z',
#      'shell.execute_reply': '2024-06-08T11:59:47.510864Z'}},
#    'outputs': [],
# ...

# %%
# !papermill "../../2_Strategies/2_Bollinger Any/B.ipynb" "../../2_Strategies/2_Bollinger Any/B.ipynb" \
    -p symbol 'NFLX' \
    -p N_WINDOWS 20 \
    -p K 2
# Out:
# Input Notebook:  ../../2_Strategies/2_Bollinger Any/B.ipynb
# Output Notebook: ../../2_Strategies/2_Bollinger Any/B.ipynb
# ...
# Executing: 100%|██████████████████████████████| 32/32 [00:07<00:00,  4.29cell/s]
